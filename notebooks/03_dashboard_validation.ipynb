# %% [markdown]
# # 03: Dashboard Validation
#
# Run tests and ensure processed datasets load correctly for the Streamlit dashboard.

# %%
import pandas as pd

try:
    df_meta = pd.read_csv('../data/processed/metadata.csv')
    df_otu = pd.read_csv('../data/processed/otu_counts.csv')
    print("Datasets loaded successfully.")
    print(f"Samples: {len(df_meta)}, OTUs: {len(df_otu.columns) - 1}")
except Exception as e:
    print("Error loading datasets:", e)
